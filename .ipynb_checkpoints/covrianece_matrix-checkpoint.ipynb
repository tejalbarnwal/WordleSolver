# %% [markdown]
# # Relation between two letters in the same word

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import string
import itertools

# %% [markdown]
# ## Defining Functions

# %%
#defining functions

#splitting word into letters
def split(word):
    return [char for char in word]

#checking if word has two letters together
def has_both_letters(pair, word):
    if (pair[0]!=pair[1]): # case of different letters
      if pair[0] in word and pair[1] in word:
          return True
      else:
          return False
    else: # case of same letters
      count = 0
      for i in word:
        if i == pair[0]:
            count += 1
      if(count>=2):
        return True
      else:
        return False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Initializing solution dataframe

# %%
solutions = pd.read_csv('/content/drive/MyDrive/valid_solutions.csv')
solutions = solutions.apply(lambda x: x.astype(str).str.upper())
solutions
# Out:
#        word
# 0     ABACK
# 1     ABASE
# 2     ABATE
# 3     ABBEY
# 4     ABBOT
# ...     ...
# 2310  YOUNG
# 2311  YOUTH
# 2312  ZEBRA
# 2313  ZESTY
# 2314  ZONAL
#
# [2315 rows x 1 columns]

# %%
solution_list = list(solutions["word"])

# %%
alphabet_list = list(string.ascii_uppercase)
# alphabet_list

# %%
pair_list = list(itertools.product(alphabet_list,alphabet_list))
# pair_list

# %% [markdown]
# ## Finding the covaraince relation

# %%
df_covariance = pd.DataFrame(columns = alphabet_list, index = alphabet_list)

# %%
for pair in pair_list:
  count = 0
  for word in solution_list:
    count = has_both_letters(pair, word) + count
  df_covariance.loc[pair[0]].at[pair[1]] = count

# %%
df_covariance
# Out:
#      A    B    C    D    E   F    G    H    I   J  ...   Q    R    S    T  \
# A   70  107  179  130  362  66  110  123  142   7  ...  12  318  224  257
# B  107   13   29   38  119   7   25   26   62   2  ...   1   94   35   56
# C  179   29   29   37  171  25   13  118  115   3  ...   2  145   85   95
# D  130   38   37   22  179  18   42   29  123   2  ...   1  129   38   61
# E  362  119  171  179  172  83  131  136  232   9  ...  13  424  256  277
# F   66    7   25   18   83  22   15   24   71   2  ...   0   78   32   57
# G  110   25   13   42  131  15   11   31   98   1  ...   0   95   39   51
# H  123   26  118   29  136  24   31   10   87   1  ...   2  101  114  135
# I  142   62  115  123  232  71   98   87   24   6  ...  11  194  147  192
# J    7    2    3    2    9   2    1    1    6   0  ...   0    6    2    8
# K   83   17   68    8   65  17    4   26   46   2  ...   5   56   69   29
# L  288   83  101   83  280  72   72   61  168   3  ...   6  114  129  123
# ...
